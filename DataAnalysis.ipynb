# %%
from typing import Callable

# %% [markdown]
# #### Publish a  message to a topic

# %%
"""Publishes multiple messages to a Pub/Sub topic with an error handler."""
from concurrent import futures
from google.cloud import pubsub_v1

# TODO(developer)
project_id = "elated-cathode-343517"
# topic_id = "projects/elated-cathode-343517/topics/SEB-data-engineering-task"
topic_id = "SEB-data-engineering-task"

publisher = pubsub_v1.PublisherClient()
topic_path = publisher.topic_path(project_id, topic_id)
publish_futures = []

def get_callback(
    publish_future: pubsub_v1.publisher.futures.Future, data: str
) -> Callable[[pubsub_v1.publisher.futures.Future], None]:
    def callback(publish_future: pubsub_v1.publisher.futures.Future) -> None:
        try:
            # Wait 60 seconds for the publish call to succeed.
            print(publish_future.result(timeout=60))
        except futures.TimeoutError:
            print(f"Publishing {data} timed out.")

    return callback

for i in range(10):
    data = str(f"Test-{i}")
    # When you publish a message, the client returns a future.
    publish_future = publisher.publish(topic_path, data.encode("utf-8"))
    # Non-blocking. Publish failures are handled in the callback function.
    publish_future.add_done_callback(get_callback(publish_future, data))
    publish_futures.append(publish_future)

# Wait for all the publish futures to resolve before exiting.
futures.wait(publish_futures, return_when=futures.ALL_COMPLETED)

print(f"Published messages with error handler to {topic_path}.")
# Out:
# 4515158904691133
# 4515158904691134
# 4515158904691135
# 4515158904691136
# 4515158904691137
# 4515158904691138
# 4515158904691139
# 4515158904691140
# 4515158904691141
# 4515158904691142
# Published messages with error handler to projects/elated-cathode-343517/topics/SEB-data-engineering-task.

# %% [markdown]
# #### Pull messages from a subscription

# %%
from concurrent.futures import TimeoutError
from google.cloud import pubsub_v1

# TODO(developer)
project_id = "elated-cathode-343517"
subscription_id = "SEB-data-engineering-task-sub"
# Number of seconds the subscriber should listen for messages
timeout = 5.0

subscriber = pubsub_v1.SubscriberClient()
# The `subscription_path` method creates a fully qualified identifier
# in the form `projects/{project_id}/subscriptions/{subscription_id}`
subscription_path = subscriber.subscription_path(project_id, subscription_id)

def callback(message: pubsub_v1.subscriber.message.Message) -> None:
    print(f"Received {message}.")
    message.ack()

streaming_pull_future = subscriber.subscribe(subscription_path, callback=callback)
print(f"Listening for messages on {subscription_path}..\n")

# Wrap subscriber in a 'with' block to automatically call close() when done.
with subscriber:
    try:
        # When `timeout` is not set, result() will block indefinitely,
        # unless an exception is encountered first.
        streaming_pull_future.result(timeout=timeout)
    except TimeoutError:
        streaming_pull_future.cancel()  # Trigger the shutdown.
        streaming_pull_future.result()  # Block until the shutdown is complete.
# Out:
# Listening for messages on projects/elated-cathode-343517/subscriptions/SEB-data-engineering-task-sub..
#
# Received Message {
#   data: b'Test-0'
#   ordering_key: ''
#   attributes: {}
# }.Received Message {
#   data: b'Test-1'
#   ordering_key: ''
#   attributes: {}
# }.
#
# Received Message {
#   data: b'Test-2'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'Test-3'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'Test-4'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'Test-5'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'Test-6'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'Test-7'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'Test-8'
#   ordering_key: ''
#   attributes: {}
# }.
# Received Message {
#   data: b'Test-9'
#   ordering_key: ''
#   attributes: {}
# }.

# %% [markdown]
# ### Data Analysis

# %%
import pandas as pd
pd.options.display.max_columns=999

# %%
df1 = pd.read_csv("Waterbase_v2018_1_T_WISE4_AggregatedData.csv", low_memory = False)

# %%
df1.head(2)
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0               UK25034780       eionetMonitoringSiteCode
# 1               UK25034780       eionetMonitoringSiteCode
#
#   parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                         RW                  CAS_35065-28-2
# 1                         RW                   CAS_7012-37-5
#
#   procedureAnalysedFraction procedureAnalysedMedia resultUom  \
# 0                     total                  water      ug/L
# 1                     total                  water      ug/L
#
#    phenomenonTimeReferenceYear parameterSamplingPeriod  procedureLOQValue  \
# 0                         2012        2012-01--2012-12              0.001
# 1                         2012        2012-01--2012-12              0.001
#
#    resultNumberOfSamples  resultQualityNumberOfSamplesBelowLOQ  \
# 0                    4.0                                   4.0
# 1                    4.0                                   4.0
#
#    resultQualityMinimumBelowLOQ  resultMinimumValue  \
# 0                           1.0               0.001
# 1                           1.0               0.001
#
#    resultQualityMeanBelowLOQ  resultMeanValue  resultQualityMaximumBelowLOQ  \
# 0                        1.0            0.001                           1.0
# 1                        1.0            0.001                           1.0
#
#    resultMaximumValue  resultQualityMedianBelowLOQ  resultMedianValue  \
# 0               0.001                          NaN                NaN
# 1               0.001                          NaN                NaN
#
#    resultStandardDeviationValue procedureAnalyticalMethod  \
# 0                           0.0                       NaN
# 1                           0.0                       NaN
#
#    parameterSampleDepth resultObservationStatus Remarks  \
# 0                   0.0                     NaN     NaN
# 1                   0.0                     NaN     NaN
#
#                                   metadata_versionId  \
# 0  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#   metadata_beginLifeSpanVersion metadata_statusCode  \
# 0       2015-11-30 00:00:00.000        experimental
# 1       2015-11-30 00:00:00.000        experimental
#
#   metadata_observationStatus metadata_statements      UID
# 0                          A                 NaN  9233859
# 1                          A                 NaN  9233860

# %%
df.dtypes
# Out:
# monitoringSiteIdentifier                 object
# monitoringSiteIdentifierScheme           object
# parameterWaterBodyCategory               object
# observedPropertyDeterminandCode          object
# procedureAnalysedFraction                object
# procedureAnalysedMedia                   object
# resultUom                                object
# phenomenonTimeReferenceYear               int64
# parameterSamplingPeriod                  object
# procedureLOQValue                       float64
# resultNumberOfSamples                   float64
# resultQualityNumberOfSamplesBelowLOQ    float64
# resultQualityMinimumBelowLOQ            float64
# resultMinimumValue                      float64
# resultQualityMeanBelowLOQ               float64
# resultMeanValue                         float64
# resultQualityMaximumBelowLOQ            float64
# resultMaximumValue                      float64
# resultQualityMedianBelowLOQ             float64
# resultMedianValue                       float64
# resultStandardDeviationValue            float64
# procedureAnalyticalMethod                object
# parameterSampleDepth                    float64
# resultObservationStatus                  object
# Remarks                                  object
# metadata_versionId                       object
# metadata_beginLifeSpanVersion            object
# metadata_statusCode                      object
# metadata_observationStatus               object
# metadata_statements                      object
# UID                                       int64
# dtype: object

# %%
df.shape
# Out:
# (3211183, 31)

# %%
df2 = pd.read_csv("Waterbase_v2018_1_T_WISE4_AggregatedDataByWaterBody.csv", low_memory = False)
df2.head(2)
# Out:
#   waterBodyIdentifier waterBodyIdentifierScheme parameterWaterBodyCategory  \
# 0              RODL06     euGroundWaterBodyCode                         GW
# 1              ROIL05     euGroundWaterBodyCode                         GW
#
#   observedPropertyDeterminandCode procedureAnalysedFraction  \
# 0                  CAS_14797-55-8                     total
# 1                   EEA_3132-01-2                     total
#
#   procedureAnalysedMedia  resultUom  phenomenonTimeReferenceYear  \
# 0                  water  mg{NO3}/L                         2007
# 1                  water       mg/L                         2007
#
#   parameterSamplingPeriod  procedureLOQValue  resultNumberOfSamples  \
# 0  2007-01-01--2007-12-31                0.0                     17
# 1  2007-01-01--2007-12-31                0.0                     15
#
#    resultQualityNumberOfSamplesBelowLOQ  resultQualityMinimumBelowLOQ  \
# 0                                   0.0                           NaN
# 1                                   0.0                           NaN
#
#    resultMinimumValue  resultQualityMeanBelowLOQ  resultMeanValue  \
# 0               0.035                        NaN            8.970
# 1               0.570                        NaN            4.266
#
#    resultQualityMaximumBelowLOQ  resultMaximumValue  \
# 0                           NaN                16.7
# 1                           NaN                 8.5
#
#    resultQualityMedianBelowLOQ  resultMedianValue  \
# 0                          NaN                NaN
# 1                          NaN                NaN
#
#    resultStandardDeviationValue  resultNumberOfSitesClass1  \
# 0                           NaN                        5.0
# 1                           NaN                        1.0
#
#    resultNumberOfSitesClass2  resultNumberOfSitesClass3  \
# 0                        4.0                        0.0
# 1                        6.0                        2.0
#
#    resultNumberOfSitesClass4  resultNumberOfSitesClass5  \
# 0                        0.0                        NaN
# 1                        NaN                        NaN
#
#   resultObservationStatus Remarks  \
# 0                     NaN     NaN
# 1                     NaN     NaN
#
#                                   metadata_versionId  \
# 0  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#   metadata_beginLifeSpanVersion metadata_statusCode  \
# 0       2015-11-30 00:00:00.000        experimental
# 1       2015-11-30 00:00:00.000        experimental
#
#   metadata_observationStatus metadata_statements    UID
# 0                          A                 NaN  17431
# 1                          A                 NaN  17472

# %%
df.dtypes
# Out:
# monitoringSiteIdentifier                 object
# monitoringSiteIdentifierScheme           object
# parameterWaterBodyCategory               object
# observedPropertyDeterminandCode          object
# procedureAnalysedFraction                object
# procedureAnalysedMedia                   object
# resultUom                                object
# phenomenonTimeReferenceYear               int64
# parameterSamplingPeriod                  object
# procedureLOQValue                       float64
# resultNumberOfSamples                   float64
# resultQualityNumberOfSamplesBelowLOQ    float64
# resultQualityMinimumBelowLOQ            float64
# resultMinimumValue                      float64
# resultQualityMeanBelowLOQ               float64
# resultMeanValue                         float64
# resultQualityMaximumBelowLOQ            float64
# resultMaximumValue                      float64
# resultQualityMedianBelowLOQ             float64
# resultMedianValue                       float64
# resultStandardDeviationValue            float64
# procedureAnalyticalMethod                object
# parameterSampleDepth                    float64
# resultObservationStatus                  object
# Remarks                                  object
# metadata_versionId                       object
# metadata_beginLifeSpanVersion            object
# metadata_statusCode                      object
# metadata_observationStatus               object
# metadata_statements                      object
# UID                                       int64
# dtype: object

# %%
df.shape
# Out:
# (3211183, 31)

# %%
BiologyEQRClassificationProcedure = pd.read_csv("Waterbase_v2018_1_T_WISE4_BiologyEQRClassificationProcedure.csv", low_memory = False)
BiologyEQRClassificationProcedure.head(2)
# Out:
#   CountryCode observedPropertyDeterminandBiologyEQRCode  \
# 0          AT                               EEA_11-04-1
# 1          AT                               EEA_11-04-1
#
#   parameterWaterBodyCategory parameterNCSWaterBodyType  \
# 0                         LW                        B1
# 1                         LW                        B2
#
#   parameterWFDIntercalibrationWaterBodyType parameterNaturalAWBHMWB  \
# 0                                       NaN                 Natural
# 1                                       NaN                 Natural
#
#    parameterICStatusOfDeterminandBiologyEQR  parameterBoundaryValueClasses12  \
# 0                                         0                              0.8
# 1                                         0                              0.8
#
#    parameterBoundaryValueClasses23  parameterBoundaryValueClasses34  \
# 0                              0.6                              0.4
# 1                              0.6                              0.4
#
#    parameterBoundaryValueClasses45  \
# 0                              0.2
# 1                              0.2
#
#   procedureBiologicalAnalyticalMethodDescription resultObservationStatus  \
# 0                                            NaN                     NaN
# 1                                            NaN                     NaN
#
#   Remarks                                 metadata_versionId  \
# 0     NaN  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1     NaN  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#   metadata_beginLifeSpanVersion metadata_statusCode  \
# 0       2015-11-30 00:00:00.000        experimental
# 1       2015-11-30 00:00:00.000        experimental
#
#   metadata_observationStatus  metadata_statements  UID
# 0                          A                  NaN    1
# 1                          A                  NaN    2

# %%
df3.dtypes
# Out:
# CountryCode                                        object
# observedPropertyDeterminandBiologyEQRCode          object
# parameterWaterBodyCategory                         object
# parameterNCSWaterBodyType                          object
# parameterWFDIntercalibrationWaterBodyType          object
# parameterNaturalAWBHMWB                            object
# parameterICStatusOfDeterminandBiologyEQR            int64
# parameterBoundaryValueClasses12                   float64
# parameterBoundaryValueClasses23                   float64
# parameterBoundaryValueClasses34                   float64
# parameterBoundaryValueClasses45                   float64
# procedureBiologicalAnalyticalMethodDescription     object
# resultObservationStatus                            object
# Remarks                                            object
# metadata_versionId                                 object
# metadata_beginLifeSpanVersion                      object
# metadata_statusCode                                object
# metadata_observationStatus                         object
# metadata_statements                               float64
# UID                                                 int64
# dtype: object

# %%
df3.shape
# Out:
# (2553, 20)

# %%
BiologyEQRData = pd.read_csv("Waterbase_v2018_1_T_WISE4_BiologyEQRData.csv", low_memory = False)
#print(df4.head(),df4.dtypes, df4.shape)

# %%
BiologyEQRData.head(2)
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0             NL94_OUDMS_A           euMonitoringSiteCode
# 1             NL94_OUDMS_A           euMonitoringSiteCode
#
#   parameterWaterBodyCategory parameterNCSWaterBodyType  \
# 0                         RW                        R8
# 1                         RW                        R8
#
#   observedPropertyDeterminandBiologyEQRCode  phenomenonTimeReferenceYear  \
# 0                              EEA_123-01-3                         2010
# 1                               EEA_13-01-4                         2007
#
#   parameterSamplingPeriod  resultEcologicalStatusClassValue  \
# 0        2010-06--2010-08                               345
# 1        2007-09--2007-11                               345
#
#    resultNumberOfSamples  resultEQRValue  resultNormalisedEQRValue  \
# 0                      1           0.509                       NaN
# 1                      5           0.518                       NaN
#
#   resultObservationStatus Remarks  \
# 0                     NaN     NaN
# 1                     NaN     NaN
#
#                                   metadata_versionId  \
# 0  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#   metadata_beginLifeSpanVersion metadata_statusCode  \
# 0       2015-11-30 00:00:00.000        experimental
# 1       2015-11-30 00:00:00.000        experimental
#
#   metadata_observationStatus  \
# 0                          U
# 1                          U
#
#                                  metadata_statements    UID
# 0  QC_LEGACY_182: resultNormalisedEQRValue cannot...  24044
# 1  QC_LEGACY_182: resultNormalisedEQRValue cannot...  24045

# %%
df5 = pd.read_csv("Waterbase_v2018_1_T_WISE4_DisaggregatedData.csv")
#print(df5.head(),df5.dtypes, df5.shape)
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3524: DtypeWarning: Columns (11,13,14,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df5.head()
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0               IT01044005           euMonitoringSiteCode
# 1               IT01044005           euMonitoringSiteCode
# 2               IT01044005           euMonitoringSiteCode
# 3               IT01044005           euMonitoringSiteCode
# 4               IT01044005           euMonitoringSiteCode
#
#   parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                         RW                   CAS_7440-38-2
# 1                         RW                   CAS_7439-89-6
# 2                         RW                   CAS_7440-66-6
# 3                         RW                   CAS_7440-66-6
# 4                         RW                   CAS_7440-02-0
#
#   procedureAnalysedFraction procedureAnalysedMedia resultUom  \
# 0                     total                  water      ug/L
# 1                     total                  water      ug/L
# 2                     total                  water      ug/L
# 3                     total                  water      ug/L
# 4                     total                  water      ug/L
#
#   phenomenonTimeSamplingDate  resultObservedValue  \
# 0    2011-06-21 00:00:00.000                  3.0
# 1    2011-06-21 00:00:00.000                 50.0
# 2    2011-08-25 00:00:00.000                 50.0
# 3    2011-07-27 00:00:00.000                 50.0
# 4    2011-09-28 00:00:00.000                  4.5
#
#    resultQualityObservedValueBelowLOQ  procedureLOQValue  \
# 0                                   1                NaN
# 1                                   1                NaN
# 2                                   1                NaN
# 3                                   1                NaN
# 4                                   0                NaN
#
#                     procedureAnalyticalMethod  parameterSampleDepth  \
# 0  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
# 1  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
# 2  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
# 3  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
# 4  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
#
#   resultObservationStatus Remarks  \
# 0                     NaN     NaN
# 1                     NaN     NaN
# 2                     NaN     NaN
# 3                     NaN     NaN
# 4                     NaN     NaN
#
#                                   metadata_versionId  \
# 0  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1  http://discomap.eea.europa.eu/data/wisesoe/der...
# 2  http://discomap.eea.europa.eu/data/wisesoe/der...
# 3  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#   metadata_beginLifeSpanVersion metadata_statusCode  \
# 0       2015-11-30 00:00:00.000        experimental
# 1       2015-11-30 00:00:00.000        experimental
# 2       2015-11-30 00:00:00.000        experimental
# 3       2015-11-30 00:00:00.000        experimental
# 4       2015-11-30 00:00:00.000        experimental
#
#   metadata_observationStatus metadata_statements      UID
# 0                          A                 NaN  1118968
# 1                          A                 NaN  1118969
# 2                          A                 NaN  1118970
# 3                          A                 NaN  1118971
# 4                          A                 NaN  1118972

# %%
MonitoringSite_DerivedData = pd.read_csv("Waterbase_v2018_1_WISE4_MonitoringSite_DerivedData.csv")

# %%
MonitoringSite_DerivedData.head(2)
# Out:
#    monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0                  ALRV_201       eionetMonitoringSiteCode
# 1  IT20-0241-CF2000103-ST01       eionetMonitoringSiteCode
#
#   waterBodyIdentifier waterBodyIdentifierScheme confidentialityStatus  \
# 0                 NaN                       NaN                     F
# 1                 NaN                       NaN                     F
#
#        lon      lat
# 0  19.8817  41.6808
# 1      NaN      NaN

# %%
df3.CountryCode.unique()
# Out:
# array(['AT', 'BG', 'NL', 'SI', 'IE', 'IT', 'BE', 'GB', 'HR', 'RO', 'ES',
#        'SE', 'SK', 'FR', 'FI', 'EE', 'PL', 'CY', 'DE', 'LT', 'NO', 'PT',
#        'LU', 'CH', 'LV'], dtype=object)

# %%
df5.head()
# Out:
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0               IT01044005           euMonitoringSiteCode
# 1               IT01044005           euMonitoringSiteCode
# 2               IT01044005           euMonitoringSiteCode
# 3               IT01044005           euMonitoringSiteCode
# 4               IT01044005           euMonitoringSiteCode
#
#   parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                         RW                   CAS_7440-38-2
# 1                         RW                   CAS_7439-89-6
# 2                         RW                   CAS_7440-66-6
# 3                         RW                   CAS_7440-66-6
# 4                         RW                   CAS_7440-02-0
#
#   procedureAnalysedFraction procedureAnalysedMedia resultUom  \
# 0                     total                  water      ug/L
# 1                     total                  water      ug/L
# 2                     total                  water      ug/L
# 3                     total                  water      ug/L
# 4                     total                  water      ug/L
#
#   phenomenonTimeSamplingDate  resultObservedValue  \
# 0    2011-06-21 00:00:00.000                  3.0
# 1    2011-06-21 00:00:00.000                 50.0
# 2    2011-08-25 00:00:00.000                 50.0
# 3    2011-07-27 00:00:00.000                 50.0
# 4    2011-09-28 00:00:00.000                  4.5
#
#    resultQualityObservedValueBelowLOQ  procedureLOQValue  \
# 0                                   1                NaN
# 1                                   1                NaN
# 2                                   1                NaN
# 3                                   1                NaN
# 4                                   0                NaN
#
#                     procedureAnalyticalMethod  parameterSampleDepth  \
# 0  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
# 1  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
# 2  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
# 3  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
# 4  APHA Standard Methods, Ed. 21th 2005, 3120                   NaN
#
#   resultObservationStatus Remarks  \
# 0                     NaN     NaN
# 1                     NaN     NaN
# 2                     NaN     NaN
# 3                     NaN     NaN
# 4                     NaN     NaN
#
#                                   metadata_versionId  \
# 0  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1  http://discomap.eea.europa.eu/data/wisesoe/der...
# 2  http://discomap.eea.europa.eu/data/wisesoe/der...
# 3  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#   metadata_beginLifeSpanVersion metadata_statusCode  \
# 0       2015-11-30 00:00:00.000        experimental
# 1       2015-11-30 00:00:00.000        experimental
# 2       2015-11-30 00:00:00.000        experimental
# 3       2015-11-30 00:00:00.000        experimental
# 4       2015-11-30 00:00:00.000        experimental
#
#   metadata_observationStatus metadata_statements      UID
# 0                          A                 NaN  1118968
# 1                          A                 NaN  1118969
# 2                          A                 NaN  1118970
# 3                          A                 NaN  1118971
# 4                          A                 NaN  1118972

# %%
df5[df5.parameterWaterBodyCategory == 'LW'].monitoringSiteIdentifier.unique()
# Out:
# array(['LTL65', 'LTL343', 'LTL312', ..., 'UK0CYMW50262', 'UK0CYMW67007',
#        'UK0CYMW23193'], dtype=object)

# %%
df3[df3.CountryCode == 'SE']
# Out:
#      CountryCode observedPropertyDeterminandBiologyEQRCode  \
# 143           SE                               EEA_11-03-0
# 144           SE                               EEA_11-03-0
# 145           SE                               EEA_11-03-0
# 146           SE                               EEA_11-03-0
# 147           SE                               EEA_11-03-0
# 151           SE                               EEA_11-04-1
# 152           SE                               EEA_11-04-1
# 479           SE                               EEA_11-03-0
# 480           SE                               EEA_11-03-0
# 481           SE                               EEA_11-03-0
# 1121          SE                               EEA_11-03-0
# 1523          SE                               EEA_11-04-1
# 1524          SE                               EEA_11-04-1
# 1525          SE                              EEA_123-04-6
# 1526          SE                              EEA_123-04-6
# 1528          SE                              EEA_124-04-9
# 1531          SE                               EEA_13-03-6
# 1532          SE                               EEA_13-04-7
# 1533          SE                               EEA_13-04-7
# 1534          SE                               EEA_13-04-7
# 2119          SE                               EEA_11-04-1
# 2120          SE                               EEA_11-04-1
# 2121          SE                               EEA_11-04-1
# 2122          SE                               EEA_11-04-1
# 2123          SE                               EEA_11-04-1
# 2124          SE                               EEA_11-04-1
# 2125          SE                               EEA_11-04-1
# 2126          SE                               EEA_11-04-1
# 2127          SE                               EEA_11-04-1
# 2128          SE                               EEA_11-04-1
# 2129          SE                               EEA_11-04-1
# 2252          SE                               EEA_13-01-4
# 2253          SE                               EEA_13-01-4
# 2254          SE                               EEA_13-01-4
# 2255          SE                              EEA_124-04-9
# 2374          SE                               EEA_11-04-1
# 2375          SE                              EEA_123-04-6
# 2376          SE                              EEA_123-04-6
# 2377          SE                              EEA_123-04-6
# 2378          SE                              EEA_123-04-6
# 2379          SE                              EEA_123-04-6
# 2380          SE                              EEA_123-04-6
# 2381          SE                              EEA_123-04-6
# 2382          SE                              EEA_123-04-6
# 2383          SE                              EEA_123-04-6
# 2384          SE                              EEA_123-04-6
# 2385          SE                              EEA_123-04-6
# 2386          SE                              EEA_123-04-6
# 2513          SE                               EEA_11-04-1
# 2514          SE                               EEA_11-04-1
# 2515          SE                               EEA_11-04-1
# 2516          SE                               EEA_11-04-1
# 2517          SE                               EEA_11-04-1
# 2518          SE                               EEA_11-04-1
# 2519          SE                               EEA_11-04-1
# 2520          SE                               EEA_11-04-1
# 2521          SE                               EEA_11-04-1
# 2522          SE                               EEA_11-04-1
#
#      parameterWaterBodyCategory  \
# 143                          LW
# 144                          LW
# 145                          LW
# 146                          LW
# 147                          LW
# 151                          LW
# 152                          LW
# 479                          LW
# 480                          LW
# 481                          LW
# 1121                         LW
# 1523                         LW
# 1524                         LW
# 1525                         LW
# 1526                         LW
# 1528                         RW
# 1531                         RW
# 1532                         RW
# 1533                         RW
# 1534                         RW
# 2119                         LW
# 2120                         LW
# 2121                         LW
# 2122                         LW
# 2123                         LW
# 2124                         LW
# 2125                         LW
# 2126                         LW
# 2127                         LW
# 2128                         LW
# 2129                         LW
# 2252                         RW
# 2253                         RW
# 2254                         RW
# 2255                         RW
# 2374                         LW
# 2375                         LW
# 2376                         LW
# 2377                         LW
# 2378                         LW
# 2379                         LW
# 2380                         LW
# 2381                         LW
# 2382                         LW
# 2383                         LW
# 2384                         LW
# 2385                         LW
# 2386                         LW
# 2513                         LW
# 2514                         LW
# 2515                         LW
# 2516                         LW
# 2517                         LW
# 2518                         LW
# 2519                         LW
# 2520                         LW
# 2521                         LW
# 2522                         LW
#
#                               parameterNCSWaterBodyType  \
# 143      North of Limes norrlandicus, colour>30 mg Pt/l
# 144   South of L. norrlandicus, Water colour<30 mg Pt/l
# 145   South of L. norrlandicus, Water colour>30 mg Pt/l
# 146      South of Limes norrlandicus, colour<30 mg Pt/l
# 147      South of Limes norrlandicus, colour>30 mg Pt/l
# 151      North of Limes norrlandicus, colour<30 mg Pt/l
# 152      North of Limes norrlandicus, colour>30 mg Pt/l
# 479                                              Alpine
# 480   North of L. norrlandicus, Water colour<30 mg Pt/l
# 481   North of L. norrlandicus, Water colour>30 mg Pt/l
# 1121     North of Limes norrlandicus, colour<30 mg Pt/l
# 1523     South of Limes norrlandicus, colour<30 mg Pt/l
# 1524     South of Limes norrlandicus, colour>30 mg Pt/l
# 1525                                                  1
# 1526                                                  2
# 1528                                            General
# 1531                                            General
# 1532                                Illies ecoregion 14
# 1533                                Illies ecoregion 20
# 1534                                Illies ecoregion 22
# 2119                                             Alpine
# 2120                                             Alpine
# 2121  North of L. norrlandicus, Water colour<30 mg Pt/l
# 2122  North of L. norrlandicus, Water colour<30 mg Pt/l
# 2123  North of L. norrlandicus, Water colour<30 mg Pt/l
# 2124  North of L. norrlandicus, Water colour<30 mg Pt/l
# 2125  North of L. norrlandicus, Water colour<30 mg Pt/l
# 2126  North of L. norrlandicus, Water colour>30 mg Pt/l
# 2127  North of L. norrlandicus, Water colour>30 mg Pt/l
# 2128  North of L. norrlandicus, Water colour>30 mg Pt/l
# 2129  North of L. norrlandicus, Water colour>30 mg Pt/l
# 2252                                Illies ecoregion 14
# 2253                                Illies ecoregion 20
# 2254                                Illies ecoregion 22
# 2255                 General (no effect by river types)
# 2374  South of L. norrlandicus, Water colour>30 mg Pt/l
# 2375                                                  1
# 2376                                                  1
# 2377                                                  1
# 2378                                                  1
# 2379                                                  1
# 2380                                                  1
# 2381                                                  1
# 2382                                                  1
# 2383                                                  1
# 2384                                                  2
# 2385                                                  2
# 2386                                                  3
# 2513  South of L. norrlandicus, Water colour<30 mg Pt/l
# 2514  South of L. norrlandicus, Water colour<30 mg Pt/l
# 2515  South of L. norrlandicus, Water colour<30 mg Pt/l
# 2516  South of L. norrlandicus, Water colour<30 mg Pt/l
# 2517  South of L. norrlandicus, Water colour<30 mg Pt/l
# 2518  South of L. norrlandicus, Water colour<30 mg Pt/l
# 2519  South of L. norrlandicus, Water colour>30 mg Pt/l
# 2520  South of L. norrlandicus, Water colour>30 mg Pt/l
# 2521  South of L. norrlandicus, Water colour>30 mg Pt/l
# 2522  South of L. norrlandicus, Water colour>30 mg Pt/l
#
#      parameterWFDIntercalibrationWaterBodyType parameterNaturalAWBHMWB  \
# 143                                        NaN                 Natural
# 144                                        NaN                 Natural
# 145                                        NaN                 Natural
# 146                                        NaN                 Natural
# 147                                        NaN                 Natural
# 151                                        NaN                 Natural
# 152                                        NaN                 Natural
# 479                                        NaN                 Natural
# 480                                        NaN                 Natural
# 481                                        NaN                 Natural
# 1121                                       NaN                 Natural
# 1523                                       NaN                 Natural
# 1524                                       NaN                 Natural
# 1525                                       NaN                 Natural
# 1526                                       NaN                 Natural
# 1528                                       NaN                 Natural
# 1531                                       NaN                 Natural
# 1532                                       NaN                 Natural
# 1533                                       NaN                 Natural
# 1534                                       NaN                 Natural
# 2119                                       NaN                 Natural
# 2120                                  LW-L-N6a                 Natural
# 2121                                       NaN                 Natural
# 2122                                   LW-L-N1                 Natural
# 2123                                  LW-L-N2a                 Natural
# 2124                                  LW-L-N3a                 Natural
# 2125                                   LW-L-N5                 Natural
# 2126                                       NaN                 Natural
# 2127                                  LW-L-N3a                 Natural
# 2128                                  LW-L-N6a                 Natural
# 2129                                  LW-L-N8a                 Natural
# 2252                                       NaN                 Natural
# 2253                                       NaN                 Natural
# 2254                                       NaN                 Natural
# 2255                                       NaN                 Natural
# 2374                                  LW-L-N8a                 Natural
# 2375                                  LW-L-N2a                 Natural
# 2376                                  LW-L-N2b                 Natural
# 2377                                  LW-L-N3a                 Natural
# 2378                                  LW-L-N3b                 Natural
# 2379                                   LW-L-N5                 Natural
# 2380                                  LW-L-N6a                 Natural
# 2381                                  LW-L-N6b                 Natural
# 2382                                   LW-L-N7                 Natural
# 2383                                   LW-L-N1                 Natural
# 2384                                  LW-L-N8a                 Natural
# 2385                                  LW-L-N8b                 Natural
# 2386                                       NaN                 Natural
# 2513                                       NaN                 Natural
# 2514                                   LW-L-N1                 Natural
# 2515                                  LW-L-N2a                 Natural
# 2516                                  LW-L-N3a                 Natural
# 2517                                   LW-L-N5                 Natural
# 2518                                  LW-L-N6a                 Natural
# 2519                                       NaN                 Natural
# 2520                                  LW-L-N3a                 Natural
# 2521                                   LW-L-N5                 Natural
# 2522                                  LW-L-N6a                 Natural
#
#       parameterICStatusOfDeterminandBiologyEQR  \
# 143                                          0
# 144                                          0
# 145                                          0
# 146                                          0
# 147                                          0
# 151                                          0
# 152                                          0
# 479                                          0
# 480                                          0
# 481                                          0
# 1121                                         0
# 1523                                         0
# 1524                                         0
# 1525                                         1
# 1526                                         1
# 1528                                         1
# 1531                                         0
# 1532                                         1
# 1533                                         1
# 1534                                         1
# 2119                                         0
# 2120                                         0
# 2121                                         0
# 2122                                         0
# 2123                                         0
# 2124                                         0
# 2125                                         0
# 2126                                         0
# 2127                                         0
# 2128                                         0
# 2129                                         0
# 2252                                         1
# 2253                                         1
# 2254                                         1
# 2255                                         1
# 2374                                         0
# 2375                                         1
# 2376                                         1
# 2377                                         1
# 2378                                         1
# 2379                                         1
# 2380                                         1
# 2381                                         1
# 2382                                         1
# 2383                                         1
# 2384                                         1
# 2385                                         1
# 2386                                         1
# 2513                                         0
# 2514                                         0
# 2515                                         0
# 2516                                         0
# 2517                                         0
# 2518                                         0
# 2519                                         0
# 2520                                         0
# 2521                                         0
# 2522                                         0
#
#       parameterBoundaryValueClasses12  parameterBoundaryValueClasses23  \
# 143                              0.89                             0.67
# 144                              0.90                             0.70
# 145                              0.88                             0.67
# 146                              0.90                             0.70
# 147                              0.88                             0.67
# 151                              0.50                             0.33
# 152                              0.50                             0.33
# 479                              0.80                             0.60
# 480                              0.67                             0.56
# 481                              0.89                             0.67
# 1121                             0.67                             0.56
# 1523                             0.50                             0.13
# 1524                             0.50                             0.20
# 1525                             0.97                             0.90
# 1526                             0.97                             0.94
# 1528                             0.89                             0.74
# 1531                             0.55                             0.40
# 1532                             0.80                             0.60
# 1533                             0.80                             0.60
# 1534                             0.80                             0.60
# 2119                             0.60                             0.34
# 2120                             0.60                             0.34
# 2121                             0.67                             0.31
# 2122                             0.67                             0.31
# 2123                             0.67                             0.31
# 2124                             0.67                             0.31
# 2125                             0.67                             0.31
# 2126                             0.75                             0.30
# 2127                             0.75                             0.30
# 2128                             0.75                             0.30
# 2129                             0.75                             0.30
# 2252                             0.90                             0.70
# 2253                             0.90                             0.70
# 2254                             0.90                             0.70
# 2255                             0.89                             0.74
# 2374                             0.50                             0.25
# 2375                             0.92                             0.86
# 2376                             0.92                             0.86
# 2377                             0.92                             0.86
# 2378                             0.92                             0.86
# 2379                             0.92                             0.86
# 2380                             0.92                             0.86
# 2381                             0.92                             0.86
# 2382                             0.92                             0.86
# 2383                             0.92                             0.86
# 2384                             0.92                             0.90
# 2385                             0.92                             0.90
# 2386                             0.93                             0.84
# 2513                             0.40                             0.20
# 2514                             0.40                             0.20
# 2515                             0.40                             0.20
# 2516                             0.40                             0.20
# 2517                             0.40                             0.20
# 2518                             0.40                             0.20
# 2519                             0.50                             0.25
# 2520                             0.50                             0.25
# 2521                             0.50                             0.25
# 2522                             0.50                             0.25
#
#       parameterBoundaryValueClasses34  parameterBoundaryValueClasses45  \
# 143                              0.44                              NaN
# 144                              0.40                              NaN
# 145                              0.33                              NaN
# 146                              0.40                              NaN
# 147                              0.33                              NaN
# 151                              0.20                              NaN
# 152                              0.20                              NaN
# 479                              0.40                              NaN
# 480                              0.44                              NaN
# 481                              0.44                              NaN
# 1121                             0.44                              NaN
# 1523                             0.10                              NaN
# 1524                             0.14                              NaN
# 1525                             0.83                              NaN
# 1526                             0.85                              NaN
# 1528                             0.56                             0.41
# 1531                             0.25                              NaN
# 1532                             0.40                             0.20
# 1533                             0.40                             0.20
# 1534                             0.40                             0.20
# 2119                             0.24                             0.18
# 2120                             0.24                             0.18
# 2121                             0.20                             0.15
# 2122                             0.20                             0.15
# 2123                             0.20                             0.15
# 2124                             0.20                             0.15
# 2125                             0.20                             0.15
# 2126                             0.20                             0.15
# 2127                             0.20                             0.15
# 2128                             0.20                             0.15
# 2129                             0.20                             0.15
# 2252                             0.45                             0.25
# 2253                             0.45                             0.25
# 2254                             0.45                             0.25
# 2255                             0.56                             0.41
# 2374                             0.11                             0.05
# 2375                             0.82                              NaN
# 2376                             0.82                              NaN
# 2377                             0.82                              NaN
# 2378                             0.82                              NaN
# 2379                             0.82                              NaN
# 2380                             0.82                              NaN
# 2381                             0.82                              NaN
# 2382                             0.82                              NaN
# 2383                             0.82                              NaN
# 2384                             0.84                              NaN
# 2385                             0.84                              NaN
# 2386                             0.57                              NaN
# 2513                             0.09                             0.04
# 2514                             0.09                             0.04
# 2515                             0.09                             0.04
# 2516                             0.09                             0.04
# 2517                             0.09                             0.04
# 2518                             0.09                             0.04
# 2519                             0.11                             0.05
# 2520                             0.11                             0.05
# 2521                             0.11                             0.05
# 2522                             0.11                             0.05
#
#          procedureBiologicalAnalyticalMethodDescription  \
# 143                                    SS-EN 15204:2006
# 144                                    SS-EN 15204:2006
# 145                                    SS-EN 15204:2006
# 146                                    SS-EN 15204:2006
# 147                                    SS-EN 15204:2006
# 151                                    SS-EN 15204:2006
# 152                                    SS-EN 15204:2006
# 479                                    SS-EN 15204:2006
# 480                                    SS-EN 15204:2006
# 481                                    SS-EN 15204:2006
# 1121                                   SS-EN 15204:2006
# 1523                                   SS-EN 15204:2006
# 1524                                   SS-EN 15204:2006
# 1525                                                NaN
# 1526                                                NaN
# 1528  http://www.havochvatten.se/download/18.64f5b32...
# 1531                       SS-EN 27 828 (ISO 7828:1985)
# 1532                       SS-EN 27 828 (ISO 7828:1985)
# 1533                       SS-EN 27 828 (ISO 7828:1985)
# 1534                       SS-EN 27 828 (ISO 7828:1985)
# 2119                                      EN 15204:2006
# 2120                                      EN 15204:2006
# 2121                                      EN 15204:2006
# 2122                                      EN 15204:2006
# 2123                                      EN 15204:2006
# 2124                                      EN 15204:2006
# 2125                                      EN 15204:2006
# 2126                                      EN 15204:2006
# 2127                                      EN 15204:2006
# 2128                                      EN 15204:2006
# 2129                                      EN 15204:2006
# 2252                          EN 27 828 (ISO 7828:1985)
# 2253                          EN 27 828 (ISO 7828:1985)
# 2254                          EN 27 828 (ISO 7828:1985)
# 2255  EN 13946:2003 (sampling) and EN 14407:2005 (an...
# 2374                                      EN 15204:2006
# 2375                                      EN 15460:2007
# 2376                                      EN 15460:2007
# 2377                                      EN 15460:2007
# 2378                                      EN 15460:2007
# 2379                                      EN 15460:2007
# 2380                                      EN 15460:2007
# 2381                                      EN 15460:2007
# 2382                                      EN 15460:2007
# 2383                                      EN 15460:2007
# 2384                                      EN 15460:2007
# 2385                                      EN 15460:2007
# 2386                                      EN 15460:2007
# 2513                                      EN 15204:2006
# 2514                                      EN 15204:2006
# 2515                                      EN 15204:2006
# 2516                                      EN 15204:2006
# 2517                                      EN 15204:2006
# 2518                                      EN 15204:2006
# 2519                                      EN 15204:2006
# 2520                                      EN 15204:2006
# 2521                                      EN 15204:2006
# 2522                                      EN 15204:2006
#
#      resultObservationStatus  \
# 143                      NaN
# 144                      NaN
# 145                      NaN
# 146                      NaN
# 147                      NaN
# 151                      NaN
# 152                      NaN
# 479                      NaN
# 480                      NaN
# 481                      NaN
# 1121                     NaN
# 1523                     NaN
# 1524                     NaN
# 1525                     NaN
# 1526                     NaN
# 1528                     NaN
# 1531                     NaN
# 1532                     NaN
# 1533                     NaN
# 1534                     NaN
# 2119                     NaN
# 2120                     NaN
# 2121                     NaN
# 2122                     NaN
# 2123                     NaN
# 2124                     NaN
# 2125                     NaN
# 2126                     NaN
# 2127                     NaN
# 2128                     NaN
# 2129                     NaN
# 2252                     NaN
# 2253                     NaN
# 2254                     NaN
# 2255                     NaN
# 2374                     NaN
# 2375                       Y
# 2376                       Y
# 2377                       Y
# 2378                       Y
# 2379                       Y
# 2380                       Y
# 2381                       Y
# 2382                       Y
# 2383                       Y
# 2384                       Y
# 2385                       Y
# 2386                       Y
# 2513                     NaN
# 2514                     NaN
# 2515                     NaN
# 2516                     NaN
# 2517                     NaN
# 2518                     NaN
# 2519                     NaN
# 2520                     NaN
# 2521                     NaN
# 2522                     NaN
#
#                                                 Remarks  \
# 143   NOTE! Only 4 classes: Approx neutral, Moderate...
# 144   NOTE! Only 4 classes: Approx neutral, Moderate...
# 145   NOTE! Only 4 classes: Approx neutral, Moderate...
# 146   NOTE! Only 4 classes: Approx neutral, Moderate...
# 147   NOTE! Only 4 classes: Approx neutral, Moderate...
# 151   NOTE! Only 4 classes: No of species incl in in...
# 152   NOTE! Only 4 classes: No of species incl in in...
# 479   NOTE! Only 4 classes: Approx neutral, Moderate...
# 480   NOTE! Only 4 classes: Approx neutral, Moderate...
# 481   NOTE! Only 4 classes: Approx neutral, Moderate...
# 1121  NOTE! Only 4 classes: Approx neutral, Moderate...
# 1523  NOTE! Only 4 classes: No of species incl in in...
# 1524  NOTE! Only 4 classes: No of species incl in in...
# 1525                               NOTE! Only 4 classes
# 1526                               NOTE! Only 4 classes
# 1528                                                NaN
# 1531  NOTE! Only 4 classes: Approx neutral, Moderate...
# 1532                                                NaN
# 1533                                                NaN
# 1534                                                NaN
# 2119  Classification based on total biovolume of phy...
# 2120  Classification based on total biovolume of phy...
# 2121  Classification based on total biovolume of phy...
# 2122  Classification based on total biovolume of phy...
# 2123  Classification based on total biovolume of phy...
# 2124  Classification based on total biovolume of phy...
# 2125  Classification based on total biovolume of phy...
# 2126  Classification based on total biovolume of phy...
# 2127  Classification based on total biovolume of phy...
# 2128  Classification based on total biovolume of phy...
# 2129  Classification based on total biovolume of phy...
# 2252  Note! Same class boundaries for all river type...
# 2253  Note! Same class boundaries for all river type...
# 2254  Note! Same class boundaries for all river type...
# 2255   Note! Same class boundaries for all river types.
# 2374  Classification based on total biovolume of phy...
# 2375  Note only 4 classes; Class borders revised in ...
# 2376  Note only 4 classes; Class borders revised in ...
# 2377  Note only 4 classes; Class borders revised in ...
# 2378  Note only 4 classes; Class borders revised in ...
# 2379  Note only 4 classes; Class borders revised in ...
# 2380  Note only 4 classes; Class borders revised in ...
# 2381  Note only 4 classes; Class borders revised in ...
# 2382  Note only 4 classes; Class borders revised in ...
# 2383  Note only 4 classes; Class borders revised in ...
# 2384  Note only 4 classes; Class borders revised in ...
# 2385  Note only 4 classes; Class borders revised in ...
# 2386  Note only 4 classes; Class borders revised in ...
# 2513  Classification based on total biovolume of phy...
# 2514  Classification based on total biovolume of phy...
# 2515  Classification based on total biovolume of phy...
# 2516  Classification based on total biovolume of phy...
# 2517  Classification based on total biovolume of phy...
# 2518  Classification based on total biovolume of phy...
# 2519  Classification based on total biovolume of phy...
# 2520  Classification based on total biovolume of phy...
# 2521  Classification based on total biovolume of phy...
# 2522  Classification based on total biovolume of phy...
#
#                                      metadata_versionId  \
# 143   http://discomap.eea.europa.eu/data/wisesoe/der...
# 144   http://discomap.eea.europa.eu/data/wisesoe/der...
# 145   http://discomap.eea.europa.eu/data/wisesoe/der...
# 146   http://discomap.eea.europa.eu/data/wisesoe/der...
# 147   http://discomap.eea.europa.eu/data/wisesoe/der...
# 151   http://discomap.eea.europa.eu/data/wisesoe/der...
# 152   http://discomap.eea.europa.eu/data/wisesoe/der...
# 479   http://discomap.eea.europa.eu/data/wisesoe/der...
# 480   http://discomap.eea.europa.eu/data/wisesoe/der...
# 481   http://discomap.eea.europa.eu/data/wisesoe/der...
# 1121  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1523  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1524  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1525  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1526  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1528  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1531  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1532  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1533  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1534  http://discomap.eea.europa.eu/data/wisesoe/der...
# 2119  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2120  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2121  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2122  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2123  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2124  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2125  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2126  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2127  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2128  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2129  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2252  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2253  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2254  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2255  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2374  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2375  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2376  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2377  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2378  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2379  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2380  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2381  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2382  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2383  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2384  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2385  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2386  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2513  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2514  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2515  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2516  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2517  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2518  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2519  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2520  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2521  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
# 2522  http://cdr.eionet.europa.eu/se/eea/wise_soe/wi...
#
#      metadata_beginLifeSpanVersion metadata_statusCode  \
# 143        2015-11-30 00:00:00.000        experimental
# 144        2015-11-30 00:00:00.000        experimental
# 145        2015-11-30 00:00:00.000        experimental
# 146        2015-11-30 00:00:00.000        experimental
# 147        2015-11-30 00:00:00.000        experimental
# 151        2015-11-30 00:00:00.000        experimental
# 152        2015-11-30 00:00:00.000        experimental
# 479        2015-11-30 00:00:00.000        experimental
# 480        2015-11-30 00:00:00.000        experimental
# 481        2015-11-30 00:00:00.000        experimental
# 1121       2015-11-30 00:00:00.000        experimental
# 1523       2015-11-30 00:00:00.000        experimental
# 1524       2015-11-30 00:00:00.000        experimental
# 1525       2015-11-30 00:00:00.000        experimental
# 1526       2015-11-30 00:00:00.000        experimental
# 1528       2015-11-30 00:00:00.000        experimental
# 1531       2015-11-30 00:00:00.000        experimental
# 1532       2015-11-30 00:00:00.000        experimental
# 1533       2015-11-30 00:00:00.000        experimental
# 1534       2015-11-30 00:00:00.000        experimental
# 2119       2017-04-05 06:55:09.000               valid
# 2120       2017-04-05 06:55:09.000               valid
# 2121       2017-04-05 06:55:09.000               valid
# 2122       2017-04-05 06:55:09.000               valid
# 2123       2017-04-05 06:55:09.000               valid
# 2124       2017-04-05 06:55:09.000               valid
# 2125       2017-04-05 06:55:09.000               valid
# 2126       2017-04-05 06:55:09.000               valid
# 2127       2017-04-05 06:55:09.000               valid
# 2128       2017-04-05 06:55:09.000               valid
# 2129       2017-04-05 06:55:09.000               valid
# 2252       2017-04-05 06:55:09.000               valid
# 2253       2017-04-05 06:55:09.000               valid
# 2254       2017-04-05 06:55:09.000               valid
# 2255       2017-04-05 06:55:09.000               valid
# 2374       2017-04-05 06:55:09.000               valid
# 2375       2017-04-05 06:55:09.000               valid
# 2376       2017-04-05 06:55:09.000               valid
# 2377       2017-04-05 06:55:09.000               valid
# 2378       2017-04-05 06:55:09.000               valid
# 2379       2017-04-05 06:55:09.000               valid
# 2380       2017-04-05 06:55:09.000               valid
# 2381       2017-04-05 06:55:09.000               valid
# 2382       2017-04-05 06:55:09.000               valid
# 2383       2017-04-05 06:55:09.000               valid
# 2384       2017-04-05 06:55:09.000               valid
# 2385       2017-04-05 06:55:09.000               valid
# 2386       2017-04-05 06:55:09.000               valid
# 2513       2017-04-05 06:55:09.000               valid
# 2514       2017-04-05 06:55:09.000               valid
# 2515       2017-04-05 06:55:09.000               valid
# 2516       2017-04-05 06:55:09.000               valid
# 2517       2017-04-05 06:55:09.000               valid
# 2518       2017-04-05 06:55:09.000               valid
# 2519       2017-04-05 06:55:09.000               valid
# 2520       2017-04-05 06:55:09.000               valid
# 2521       2017-04-05 06:55:09.000               valid
# 2522       2017-04-05 06:55:09.000               valid
#
#      metadata_observationStatus  metadata_statements   UID
# 143                           A                  NaN  2460
# 144                           A                  NaN  2461
# 145                           A                  NaN  2462
# 146                           A                  NaN  2463
# 147                           A                  NaN  2464
# 151                           A                  NaN  2468
# 152                           A                  NaN  2469
# 479                           A                  NaN  2456
# 480                           A                  NaN  2457
# 481                           A                  NaN  2458
# 1121                          A                  NaN  2459
# 1523                          A                  NaN  2472
# 1524                          A                  NaN  2473
# 1525                          A                  NaN  2474
# 1526                          A                  NaN  2475
# 1528                          A                  NaN  2477
# 1531                          A                  NaN  2481
# 1532                          A                  NaN  2482
# 1533                          A                  NaN  2483
# 1534                          A                  NaN  2484
# 2119                          A                  NaN  4077
# 2120                          A                  NaN  4078
# 2121                          A                  NaN  4079
# 2122                          A                  NaN  4080
# 2123                          A                  NaN  4081
# 2124                          A                  NaN  4082
# 2125                          A                  NaN  4083
# 2126                          A                  NaN  4084
# 2127                          A                  NaN  4085
# 2128                          A                  NaN  4086
# 2129                          A                  NaN  4087
# 2252                          A                  NaN  4111
# 2253                          A                  NaN  4112
# 2254                          A                  NaN  4113
# 2255                          A                  NaN  4114
# 2374                          A                  NaN  4098
# 2375                          A                  NaN  4099
# 2376                          A                  NaN  4100
# 2377                          A                  NaN  4101
# 2378                          A                  NaN  4102
# 2379                          A                  NaN  4103
# 2380                          A                  NaN  4104
# 2381                          A                  NaN  4105
# 2382                          A                  NaN  4106
# 2383                          A                  NaN  4107
# 2384                          A                  NaN  4108
# 2385                          A                  NaN  4109
# 2386                          A                  NaN  4110
# 2513                          A                  NaN  4088
# 2514                          A                  NaN  4089
# 2515                          A                  NaN  4090
# 2516                          A                  NaN  4091
# 2517                          A                  NaN  4092
# 2518                          A                  NaN  4093
# 2519                          A                  NaN  4094
# 2520                          A                  NaN  4095
# 2521                          A                  NaN  4096
# 2522                          A                  NaN  4097

# %%
df1.columns
# Out:
# Index(['monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
#        'parameterWaterBodyCategory', 'observedPropertyDeterminandCode',
#        'procedureAnalysedFraction', 'procedureAnalysedMedia', 'resultUom',
#        'phenomenonTimeReferenceYear', 'parameterSamplingPeriod',
#        'procedureLOQValue', 'resultNumberOfSamples',
#        'resultQualityNumberOfSamplesBelowLOQ', 'resultQualityMinimumBelowLOQ',
#        'resultMinimumValue', 'resultQualityMeanBelowLOQ', 'resultMeanValue',
#        'resultQualityMaximumBelowLOQ', 'resultMaximumValue',
#        'resultQualityMedianBelowLOQ', 'resultMedianValue',
#        'resultStandardDeviationValue', 'procedureAnalyticalMethod',
#        'parameterSampleDepth', 'resultObservationStatus', 'Remarks',
#        'metadata_versionId', 'metadata_beginLifeSpanVersion',
#        'metadata_statusCode', 'metadata_observationStatus',
#        'metadata_statements', 'UID'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['waterBodyIdentifier', 'waterBodyIdentifierScheme',
#        'parameterWaterBodyCategory', 'observedPropertyDeterminandCode',
#        'procedureAnalysedFraction', 'procedureAnalysedMedia', 'resultUom',
#        'phenomenonTimeReferenceYear', 'parameterSamplingPeriod',
#        'procedureLOQValue', 'resultNumberOfSamples',
#        'resultQualityNumberOfSamplesBelowLOQ', 'resultQualityMinimumBelowLOQ',
#        'resultMinimumValue', 'resultQualityMeanBelowLOQ', 'resultMeanValue',
#        'resultQualityMaximumBelowLOQ', 'resultMaximumValue',
#        'resultQualityMedianBelowLOQ', 'resultMedianValue',
#        'resultStandardDeviationValue', 'resultNumberOfSitesClass1',
#        'resultNumberOfSitesClass2', 'resultNumberOfSitesClass3',
#        'resultNumberOfSitesClass4', 'resultNumberOfSitesClass5',
#        'resultObservationStatus', 'Remarks', 'metadata_versionId',
#        'metadata_beginLifeSpanVersion', 'metadata_statusCode',
#        'metadata_observationStatus', 'metadata_statements', 'UID'],
#       dtype='object')

# %%
df5.columns
# Out:
# Index(['monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
#        'parameterWaterBodyCategory', 'observedPropertyDeterminandCode',
#        'procedureAnalysedFraction', 'procedureAnalysedMedia', 'resultUom',
#        'phenomenonTimeSamplingDate', 'resultObservedValue',
#        'resultQualityObservedValueBelowLOQ', 'procedureLOQValue',
#        'procedureAnalyticalMethod', 'parameterSampleDepth',
#        'resultObservationStatus', 'Remarks', 'metadata_versionId',
#        'metadata_beginLifeSpanVersion', 'metadata_statusCode',
#        'metadata_observationStatus', 'metadata_statements', 'UID'],
#       dtype='object')

# %%
df6.columns
# Out:
# Index(['monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
#        'waterBodyIdentifier', 'waterBodyIdentifierScheme',
#        'confidentialityStatus', 'lon', 'lat'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['CountryCode', 'observedPropertyDeterminandBiologyEQRCode',
#        'parameterWaterBodyCategory', 'parameterNCSWaterBodyType',
#        'parameterWFDIntercalibrationWaterBodyType', 'parameterNaturalAWBHMWB',
#        'parameterICStatusOfDeterminandBiologyEQR',
#        'parameterBoundaryValueClasses12', 'parameterBoundaryValueClasses23',
#        'parameterBoundaryValueClasses34', 'parameterBoundaryValueClasses45',
#        'procedureBiologicalAnalyticalMethodDescription',
#        'resultObservationStatus', 'Remarks', 'metadata_versionId',
#        'metadata_beginLifeSpanVersion', 'metadata_statusCode',
#        'metadata_observationStatus', 'metadata_statements', 'UID'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
#        'parameterWaterBodyCategory', 'parameterNCSWaterBodyType',
#        'observedPropertyDeterminandBiologyEQRCode',
#        'phenomenonTimeReferenceYear', 'parameterSamplingPeriod',
#        'resultEcologicalStatusClassValue', 'resultNumberOfSamples',
#        'resultEQRValue', 'resultNormalisedEQRValue', 'resultObservationStatus',
#        'Remarks', 'metadata_versionId', 'metadata_beginLifeSpanVersion',
#        'metadata_statusCode', 'metadata_observationStatus',
#        'metadata_statements', 'UID'],
#       dtype='object')

# %%
(df4.monitoringSiteIdentifier.isin(df6.monitoringSiteIdentifier.unique())).sum()
# Out:
# 29716

# %%
(df6.monitoringSiteIdentifier.isin(df4.monitoringSiteIdentifier.unique())).sum()
# Out:
# 9776

# %%
df6.shape
# Out:
# (56464, 7)

# %%
df4.shape
# Out:
# (29741, 19)

# %%
29741 - 29716
# Out:
# 25

# %%
print(df2.shape, df6.shape)
# Out:
# (20251, 34) (56464, 7)

# %%
(df2.waterBodyIdentifier.isin(df6.waterBodyIdentifier.unique())).sum()
# Out:
# 7026

# %%
(df6.waterBodyIdentifier.isin(df2.waterBodyIdentifier.unique())).sum()
# Out:
# 2823

# %% [markdown]
# ### Data Quality on Total WaterBodies

# %%
df6.head(2)
# Out:
#    monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0                  ALRV_201       eionetMonitoringSiteCode
# 1  IT20-0241-CF2000103-ST01       eionetMonitoringSiteCode
#
#   waterBodyIdentifier waterBodyIdentifierScheme confidentialityStatus  \
# 0                 NaN                       NaN                     F
# 1                 NaN                       NaN                     F
#
#        lon      lat
# 0  19.8817  41.6808
# 1      NaN      NaN

# %% [markdown]
# #### 4.3% of waterbodies have null waterBodyIdentifier

# %%
df6.waterBodyIdentifier.isna().sum() / df6.shape[0]
# Out:
# 0.043514451686030034

# %% [markdown]
# #### 23.4% of waterbodies have missing geographical coordinates (latitude and longitude)

# %%
round(100 * df6.lon.isna().sum() / df6.shape[0], 2)
# Out:
# 23.39

# %% [markdown]
# #### 1.4% of data has duplicate monitoringSiteIdentifier

# %%
round(100 * MonitoringSite_DerivedData[MonitoringSite_DerivedData.monitoringSiteIdentifier.duplicated()].shape[0] / MonitoringSite_DerivedData.shape[0], 2)
# Out:
# 1.46

# %%
MonitoringSite_DerivedData[MonitoringSite_DerivedData.monitoringSiteIdentifier == "BEVL_VMM_581000"]
# Out:
#      monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 4580          BEVL_VMM_581000           euMonitoringSiteCode
# 4581          BEVL_VMM_581000           euMonitoringSiteCode
#
#      waterBodyIdentifier waterBodyIdentifierScheme confidentialityStatus  \
# 4580           BEVL08_48    euSurfaceWaterBodyCode                     F
# 4581           BEVL08_48    euSurfaceWaterBodyCode                     F
#
#           lon      lat
# 4580  3.18859  50.8011
# 4581  3.18859  50.8011

# %% [markdown]
# ## For country Sweden (SE)

# %%
Sweden = BiologyEQRClassificationProcedure[BiologyEQRClassificationProcedure.CountryCode == "SE"].reset_index(drop=True)

# %%
Sweden.sort_values('observedPropertyDeterminandBiologyEQRCode').head()
# Out:
#   CountryCode observedPropertyDeterminandBiologyEQRCode  \
# 0          SE                               EEA_11-03-0
# 1          SE                               EEA_11-03-0
# 2          SE                               EEA_11-03-0
# 3          SE                               EEA_11-03-0
# 4          SE                               EEA_11-03-0
#
#   parameterWaterBodyCategory  \
# 0                         LW
# 1                         LW
# 2                         LW
# 3                         LW
# 4                         LW
#
#                            parameterNCSWaterBodyType  \
# 0     North of Limes norrlandicus, colour>30 mg Pt/l
# 1  South of L. norrlandicus, Water colour<30 mg Pt/l
# 2  South of L. norrlandicus, Water colour>30 mg Pt/l
# 3     South of Limes norrlandicus, colour<30 mg Pt/l
# 4     South of Limes norrlandicus, colour>30 mg Pt/l
#
#   parameterWFDIntercalibrationWaterBodyType parameterNaturalAWBHMWB  \
# 0                                       NaN                 Natural
# 1                                       NaN                 Natural
# 2                                       NaN                 Natural
# 3                                       NaN                 Natural
# 4                                       NaN                 Natural
#
#    parameterICStatusOfDeterminandBiologyEQR  parameterBoundaryValueClasses12  \
# 0                                         0                             0.89
# 1                                         0                             0.90
# 2                                         0                             0.88
# 3                                         0                             0.90
# 4                                         0                             0.88
#
#    parameterBoundaryValueClasses23  parameterBoundaryValueClasses34  \
# 0                             0.67                             0.44
# 1                             0.70                             0.40
# 2                             0.67                             0.33
# 3                             0.70                             0.40
# 4                             0.67                             0.33
#
#    parameterBoundaryValueClasses45  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#   procedureBiologicalAnalyticalMethodDescription resultObservationStatus  \
# 0                               SS-EN 15204:2006                     NaN
# 1                               SS-EN 15204:2006                     NaN
# 2                               SS-EN 15204:2006                     NaN
# 3                               SS-EN 15204:2006                     NaN
# 4                               SS-EN 15204:2006                     NaN
#
#                                              Remarks  \
# 0  NOTE! Only 4 classes: Approx neutral, Moderate...
# 1  NOTE! Only 4 classes: Approx neutral, Moderate...
# 2  NOTE! Only 4 classes: Approx neutral, Moderate...
# 3  NOTE! Only 4 classes: Approx neutral, Moderate...
# 4  NOTE! Only 4 classes: Approx neutral, Moderate...
#
#                                   metadata_versionId  \
# 0  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1  http://discomap.eea.europa.eu/data/wisesoe/der...
# 2  http://discomap.eea.europa.eu/data/wisesoe/der...
# 3  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#   metadata_beginLifeSpanVersion metadata_statusCode  \
# 0       2015-11-30 00:00:00.000        experimental
# 1       2015-11-30 00:00:00.000        experimental
# 2       2015-11-30 00:00:00.000        experimental
# 3       2015-11-30 00:00:00.000        experimental
# 4       2015-11-30 00:00:00.000        experimental
#
#   metadata_observationStatus  metadata_statements   UID
# 0                          A                  NaN  2460
# 1                          A                  NaN  2461
# 2                          A                  NaN  2462
# 3                          A                  NaN  2463
# 4                          A                  NaN  2464

# %%
cols = list(set(Sweden.columns) - set(['UID', 'parameterNCSWaterBodyType']))

# %%
Sweden[Sweden[cols].duplicated()].shape
# Out:
# (9, 20)

# %%
Sweden.shape
# Out:
# (58, 20)

# %%
Sweden.isna().sum()
# Out:
# CountryCode                                        0
# observedPropertyDeterminandBiologyEQRCode          0
# parameterWaterBodyCategory                         0
# parameterNCSWaterBodyType                          0
# parameterWFDIntercalibrationWaterBodyType         30
# parameterNaturalAWBHMWB                            0
# parameterICStatusOfDeterminandBiologyEQR           0
# parameterBoundaryValueClasses12                    0
# parameterBoundaryValueClasses23                    0
# parameterBoundaryValueClasses34                    0
# parameterBoundaryValueClasses45                   28
# procedureBiologicalAnalyticalMethodDescription     2
# resultObservationStatus                           46
# Remarks                                            4
# metadata_versionId                                 0
# metadata_beginLifeSpanVersion                      0
# metadata_statusCode                                0
# metadata_observationStatus                         0
# metadata_statements                               58
# UID                                                0
# dtype: int64

# %%
Sweden_EQRData = pd.merge(
    Sweden,
    df4,
    how='inner',
    on='observedPropertyDeterminandBiologyEQRCode'
)

# %%
Merged_BiologyEQRData = pd.merge(
    MonitoringSite_DerivedData,
    df4,
    how='inner',
    on='monitoringSiteIdentifier'
)

# %%
Sweden_BiologyEQRData = pd.merge(
    Sweden_EQRData,
    Merged_BiologyEQRData,
    on='monitoringSiteIdentifier'
)

# %%
Sweden_BiologyEQRData.waterBodyIdentifier.unique().shape
# Out:
# (7263,)

# %%
MonitoringSite_DerivedData.waterBodyIdentifier.unique().shape
# Out:
# (22289,)

# %% [markdown]
# #### We do have monitoring data but that is not associated to any waterbody

# %%
Sweden_BiologyEQRData.waterBodyIdentifier.isna().sum()
# Out:
# 5201

# %%
7263/22289
# Out:
# 0.3258558033110503

# %%
print(df6.shape, df4.shape)
# Out:
# (56464, 7) (29741, 19)

# %%
Merged_BiologyEQRData.dtypes
# Out:
# monitoringSiteIdentifier                      object
# monitoringSiteIdentifierScheme_x              object
# waterBodyIdentifier                           object
# waterBodyIdentifierScheme                     object
# confidentialityStatus                         object
# lon                                          float64
# lat                                          float64
# monitoringSiteIdentifierScheme_y              object
# parameterWaterBodyCategory                    object
# parameterNCSWaterBodyType                     object
# observedPropertyDeterminandBiologyEQRCode     object
# phenomenonTimeReferenceYear                    int64
# parameterSamplingPeriod                       object
# resultEcologicalStatusClassValue               int64
# resultNumberOfSamples                          int64
# resultEQRValue                               float64
# resultNormalisedEQRValue                     float64
# resultObservationStatus                       object
# Remarks                                       object
# metadata_versionId                            object
# metadata_beginLifeSpanVersion                 object
# metadata_statusCode                           object
# metadata_observationStatus                    object
# metadata_statements                           object
# UID                                            int64
# dtype: object

# %%
{
    "CountryCode": "SE",
    "WaterBodies": [
        {
            waterbody 1 ,
            monitoringInfo: [
                {
                    monitoring info 1
                },
                {
                    monitoring info 2
                }
            ]
        },
        {
            waterbody 2,            
            monitoringInfo: [
                {
                    monitoring info 1
                },
                {
                    monitoring info 2
                }
            ]
        }
    ]
}

# %% [markdown]
# ### Export to AVRO

# %%
from fastavro import writer, reader, parse_schema

# %%
Sweden.dtypes
# Out:
# CountryCode                                        object
# observedPropertyDeterminandBiologyEQRCode          object
# parameterWaterBodyCategory                         object
# parameterNCSWaterBodyType                          object
# parameterWFDIntercalibrationWaterBodyType          object
# parameterNaturalAWBHMWB                            object
# parameterICStatusOfDeterminandBiologyEQR            int64
# parameterBoundaryValueClasses12                   float64
# parameterBoundaryValueClasses23                   float64
# parameterBoundaryValueClasses34                   float64
# parameterBoundaryValueClasses45                   float64
# procedureBiologicalAnalyticalMethodDescription     object
# resultObservationStatus                            object
# Remarks                                            object
# metadata_versionId                                 object
# metadata_beginLifeSpanVersion                      object
# metadata_statusCode                                object
# metadata_observationStatus                         object
# metadata_statements                               float64
# UID                                                 int64
# dtype: object

# %%
Sweden.shape
# Out:
# (58, 20)

# %%
Sweden.isna().sum()
# Out:
# CountryCode                                        0
# observedPropertyDeterminandBiologyEQRCode          0
# parameterWaterBodyCategory                         0
# parameterNCSWaterBodyType                          0
# parameterWFDIntercalibrationWaterBodyType          0
# parameterNaturalAWBHMWB                            0
# parameterICStatusOfDeterminandBiologyEQR           0
# parameterBoundaryValueClasses12                    0
# parameterBoundaryValueClasses23                    0
# parameterBoundaryValueClasses34                    0
# parameterBoundaryValueClasses45                   28
# procedureBiologicalAnalyticalMethodDescription     2
# resultObservationStatus                           46
# Remarks                                            4
# metadata_versionId                                 0
# metadata_beginLifeSpanVersion                      0
# metadata_statusCode                                0
# metadata_observationStatus                         0
# metadata_statements                               58
# UID                                                0
# dtype: int64

# %%
Sweden.parameterWFDIntercalibrationWaterBodyType.fillna('', inplace=True)
Sweden.resultObservationStatus.fillna('', inplace=True)
Sweden.Remarks.fillna('', inplace=True)
Sweden.procedureBiologicalAnalyticalMethodDescription.fillna('', inplace=True)

# %%
schema = {
    'doc': 'Waterbase - Water quality',
    'name': 'Water Quality',
    'namespace': 'Quality',
    'type': 'record',
    'fields': [
        {'name': 'CountryCode', 'type': 'string'},
        {'name': 'observedPropertyDeterminandBiologyEQRCode', 'type': 'string'},
        {'name': 'parameterWaterBodyCategory', 'type': 'string'},
        {'name': 'parameterNCSWaterBodyType', 'type': 'string'},
        {'name': 'parameterWFDIntercalibrationWaterBodyType', 'type': 'string'},
        {'name': 'parameterNaturalAWBHMWB', 'type': 'string'},
        {'name': 'parameterICStatusOfDeterminandBiologyEQR', 'type': 'int'},
        {'name': 'parameterBoundaryValueClasses12', 'type': 'float'},
        {'name': 'parameterBoundaryValueClasses23', 'type': 'float'},
        {'name': 'parameterBoundaryValueClasses34', 'type': 'float'},
        {'name': 'parameterBoundaryValueClasses45', 'type': 'float'},
        {'name': 'procedureBiologicalAnalyticalMethodDescription', 'type': 'string'},
        {'name': 'resultObservationStatus', 'type': 'string'},
        {'name': 'Remarks', 'type': 'string'},
        {'name': 'metadata_versionId', 'type': 'string'},
        {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'},
        {'name': 'metadata_statusCode', 'type': 'string'},
        {'name': 'metadata_observationStatus', 'type': 'string'},
        {'name': 'metadata_statements', 'type': 'float'},
        {'name': 'UID', 'type': 'int'},   
    ]
}
parsed_schema = parse_schema(schema)

# %%
# 2. Convert pd.DataFrame to records - list of dictionaries
records = Sweden.to_dict('records')

# 3. Write to Avro file
with open('Waterbase_v2018_1_WISE4_MonitoringSite_DerivedData.avro', 'wb') as out:
    writer(out, parsed_schema, records)

# %%
df4.columns
# Out:
# Index(['monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
#        'parameterWaterBodyCategory', 'parameterNCSWaterBodyType',
#        'observedPropertyDeterminandBiologyEQRCode',
#        'phenomenonTimeReferenceYear', 'parameterSamplingPeriod',
#        'resultEcologicalStatusClassValue', 'resultNumberOfSamples',
#        'resultEQRValue', 'resultNormalisedEQRValue', 'resultObservationStatus',
#        'Remarks', 'metadata_versionId', 'metadata_beginLifeSpanVersion',
#        'metadata_statusCode', 'metadata_observationStatus',
#        'metadata_statements', 'UID'],
#       dtype='object')

# %% [markdown]
# #### Returns only the observedPropertyDeterminandBiologyEQRCode which are in Sweden DF

# %%
Sweden_BiologyEQRData = df4[
    df4.observedPropertyDeterminandBiologyEQRCode.isin(
        Sweden.observedPropertyDeterminandBiologyEQRCode.unique()
    )
]

# %%
df4.shape
# Out:
# (29741, 19)

# %%
for k,v in Sweden_BiologyEQRData.dtypes.to_dict().items():
    print({"name": k, "type":'string' if v == object else 'int' if v == 'int' else 'float'})
# Out:
# {'name': 'monitoringSiteIdentifier', 'type': 'string'}
# {'name': 'monitoringSiteIdentifierScheme', 'type': 'string'}
# {'name': 'parameterWaterBodyCategory', 'type': 'string'}
# {'name': 'parameterNCSWaterBodyType', 'type': 'string'}
# {'name': 'observedPropertyDeterminandBiologyEQRCode', 'type': 'string'}
# {'name': 'phenomenonTimeReferenceYear', 'type': 'int'}
# {'name': 'parameterSamplingPeriod', 'type': 'string'}
# {'name': 'resultEcologicalStatusClassValue', 'type': 'int'}
# {'name': 'resultNumberOfSamples', 'type': 'int'}
# {'name': 'resultEQRValue', 'type': 'float'}
# {'name': 'resultNormalisedEQRValue', 'type': 'float'}
# {'name': 'resultObservationStatus', 'type': 'string'}
# {'name': 'Remarks', 'type': 'string'}
# {'name': 'metadata_versionId', 'type': 'string'}
# {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'}
# {'name': 'metadata_statusCode', 'type': 'string'}
# {'name': 'metadata_observationStatus', 'type': 'string'}
# {'name': 'metadata_statements', 'type': 'string'}
# {'name': 'UID', 'type': 'int'}

# %%
for k,v in Sweden_BiologyEQRData.dtypes.to_dict().items():
    if v == object and Sweden_BiologyEQRData[k].isna().sum():
        print(v)
        Sweden_BiologyEQRData[k].fillna('', inplace=True)
# Out:
# object
# object
# object
# object
# object
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
Sweden_BiologyEQRData.isna().sum()
# Out:
# monitoringSiteIdentifier                        0
# monitoringSiteIdentifierScheme                  0
# parameterWaterBodyCategory                      0
# parameterNCSWaterBodyType                       0
# observedPropertyDeterminandBiologyEQRCode       0
# phenomenonTimeReferenceYear                     0
# parameterSamplingPeriod                         0
# resultEcologicalStatusClassValue                0
# resultNumberOfSamples                           0
# resultEQRValue                               1896
# resultNormalisedEQRValue                     8616
# resultObservationStatus                         0
# Remarks                                         0
# metadata_versionId                              0
# metadata_beginLifeSpanVersion                   0
# metadata_statusCode                             0
# metadata_observationStatus                      0
# metadata_statements                             0
# UID                                             0
# dtype: int64

# %%
Sweden_BiologyEQRData.parameterNCSWaterBodyType.fillna('', inplace=True)
Sweden_BiologyEQRData.parameterSamplingPeriod.fillna('', inplace=True)
Sweden_BiologyEQRData.resultObservationStatus.fillna('', inplace=True)
Sweden_BiologyEQRData.Remarks.fillna('', inplace=True)
Sweden_BiologyEQRData.metadata_statements.fillna('', inplace=True)

# %%
schema = {
    'doc': 'Waterbase - Water quality',
    'name': 'Water Quality - BiologyEQRData',
    'namespace': 'BiologyEQRData',
    'type': 'record',
    'fields': [
        {'name': 'monitoringSiteIdentifier', 'type': 'string'},
        {'name': 'monitoringSiteIdentifierScheme', 'type': 'string'},
        {'name': 'parameterWaterBodyCategory', 'type': 'string'},
        {'name': 'parameterNCSWaterBodyType', 'type': 'string'},
        {'name': 'observedPropertyDeterminandBiologyEQRCode', 'type': 'string'},
        {'name': 'phenomenonTimeReferenceYear', 'type': 'int'},
        {'name': 'parameterSamplingPeriod', 'type': 'string'},
        {'name': 'resultEcologicalStatusClassValue', 'type': 'int'},
        {'name': 'resultNumberOfSamples', 'type': 'int'},
        {'name': 'resultEQRValue', 'type': 'float'},
        {'name': 'resultNormalisedEQRValue', 'type': 'float'},
        {'name': 'resultObservationStatus', 'type': 'string'},
        {'name': 'Remarks', 'type': 'string'},
        {'name': 'metadata_versionId', 'type': 'string'},
        {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'},
        {'name': 'metadata_statusCode', 'type': 'string'},
        {'name': 'metadata_observationStatus', 'type': 'string'},
        {'name': 'metadata_statements', 'type': 'string'},
        {'name': 'UID', 'type': 'int'},
    ]
}
parsed_schema = parse_schema(schema)

# %%
# 2. Convert pd.DataFrame to records - list of dictionaries
records = Sweden_BiologyEQRData.to_dict('records')

# 3. Write to Avro file
with open('Waterbase_v2018_1_T_WISE4_BiologyEQRData.avro', 'wb') as out:
    writer(out, parsed_schema, records)

# %%
Sweden_BiologyEQRData.columns
# Out:
# Index(['monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
#        'parameterWaterBodyCategory', 'parameterNCSWaterBodyType',
#        'observedPropertyDeterminandBiologyEQRCode',
#        'phenomenonTimeReferenceYear', 'parameterSamplingPeriod',
#        'resultEcologicalStatusClassValue', 'resultNumberOfSamples',
#        'resultEQRValue', 'resultNormalisedEQRValue', 'resultObservationStatus',
#        'Remarks', 'metadata_versionId', 'metadata_beginLifeSpanVersion',
#        'metadata_statusCode', 'metadata_observationStatus',
#        'metadata_statements', 'UID'],
#       dtype='object')

# %%
Sweden_df1 = df1[
    df1.monitoringSiteIdentifier.isin(Sweden_BiologyEQRData.monitoringSiteIdentifier.unique())
]

# %%
for k,v in Sweden_df1.dtypes.to_dict().items():
    if v == object and Sweden_df1[k].isna().sum():
        print(k)
        Sweden_df1[k].fillna('', inplace=True)

# %%
for k,v in Sweden_df1.dtypes.to_dict().items():
    print({"name": k, "type":'string' if v == object else 'int' if v == 'int' else 'float'})
# Out:
# {'name': 'monitoringSiteIdentifier', 'type': 'string'}
# {'name': 'monitoringSiteIdentifierScheme', 'type': 'string'}
# {'name': 'parameterWaterBodyCategory', 'type': 'string'}
# {'name': 'observedPropertyDeterminandCode', 'type': 'string'}
# {'name': 'procedureAnalysedFraction', 'type': 'string'}
# {'name': 'procedureAnalysedMedia', 'type': 'string'}
# {'name': 'resultUom', 'type': 'string'}
# {'name': 'phenomenonTimeReferenceYear', 'type': 'int'}
# {'name': 'parameterSamplingPeriod', 'type': 'string'}
# {'name': 'procedureLOQValue', 'type': 'float'}
# {'name': 'resultNumberOfSamples', 'type': 'float'}
# {'name': 'resultQualityNumberOfSamplesBelowLOQ', 'type': 'float'}
# {'name': 'resultQualityMinimumBelowLOQ', 'type': 'float'}
# {'name': 'resultMinimumValue', 'type': 'float'}
# {'name': 'resultQualityMeanBelowLOQ', 'type': 'float'}
# {'name': 'resultMeanValue', 'type': 'float'}
# {'name': 'resultQualityMaximumBelowLOQ', 'type': 'float'}
# {'name': 'resultMaximumValue', 'type': 'float'}
# {'name': 'resultQualityMedianBelowLOQ', 'type': 'float'}
# {'name': 'resultMedianValue', 'type': 'float'}
# {'name': 'resultStandardDeviationValue', 'type': 'float'}
# {'name': 'procedureAnalyticalMethod', 'type': 'string'}
# {'name': 'parameterSampleDepth', 'type': 'float'}
# {'name': 'resultObservationStatus', 'type': 'string'}
# {'name': 'Remarks', 'type': 'string'}
# {'name': 'metadata_versionId', 'type': 'string'}
# {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'}
# {'name': 'metadata_statusCode', 'type': 'string'}
# {'name': 'metadata_observationStatus', 'type': 'string'}
# {'name': 'metadata_statements', 'type': 'string'}
# {'name': 'UID', 'type': 'int'}

# %%
schema = {
    'doc': 'Waterbase - Water quality',
    'name': 'Water Quality - BiologyEQRData',
    'namespace': 'BiologyEQRData',
    'type': 'record',
    'fields': [
        {'name': 'monitoringSiteIdentifier', 'type': 'string'},
        {'name': 'monitoringSiteIdentifierScheme', 'type': 'string'},
        {'name': 'parameterWaterBodyCategory', 'type': 'string'},
        {'name': 'observedPropertyDeterminandCode', 'type': 'string'},
        {'name': 'procedureAnalysedFraction', 'type': 'string'},
        {'name': 'procedureAnalysedMedia', 'type': 'string'},
        {'name': 'resultUom', 'type': 'string'},
        {'name': 'phenomenonTimeReferenceYear', 'type': 'int'},
        {'name': 'parameterSamplingPeriod', 'type': 'string'},
        {'name': 'procedureLOQValue', 'type': 'float'},
        {'name': 'resultNumberOfSamples', 'type': 'float'},
        {'name': 'resultQualityNumberOfSamplesBelowLOQ', 'type': 'float'},
        {'name': 'resultQualityMinimumBelowLOQ', 'type': 'float'},
        {'name': 'resultMinimumValue', 'type': 'float'},
        {'name': 'resultQualityMeanBelowLOQ', 'type': 'float'},
        {'name': 'resultMeanValue', 'type': 'float'},
        {'name': 'resultQualityMaximumBelowLOQ', 'type': 'float'},
        {'name': 'resultMaximumValue', 'type': 'float'},
        {'name': 'resultQualityMedianBelowLOQ', 'type': 'float'},
        {'name': 'resultMedianValue', 'type': 'float'},
        {'name': 'resultStandardDeviationValue', 'type': 'float'},
        {'name': 'procedureAnalyticalMethod', 'type': 'string'},
        {'name': 'parameterSampleDepth', 'type': 'float'},
        {'name': 'resultObservationStatus', 'type': 'string'},
        {'name': 'Remarks', 'type': 'string'},
        {'name': 'metadata_versionId', 'type': 'string'},
        {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'},
        {'name': 'metadata_statusCode', 'type': 'string'},
        {'name': 'metadata_observationStatus', 'type': 'string'},
        {'name': 'metadata_statements', 'type': 'string'},
        {'name': 'UID', 'type': 'int'},
    ]
}
parsed_schema = parse_schema(schema)

# %%
# 2. Convert pd.DataFrame to records - list of dictionaries
records = Sweden_df1.to_dict('records')

# 3. Write to Avro file
with open('Waterbase_v2018_1_T_WISE4_AggregatedData.avro', 'wb') as out:
    writer(out, parsed_schema, records)

# %%
Sweden_df2 = df2[
    df2.observedPropertyDeterminandCode.isin(Sweden_df1.observedPropertyDeterminandCode.unique())
]

# %%
for k,v in Sweden_df2.dtypes.to_dict().items():
    if v == object and Sweden_df2[k].isna().sum():
        print(k)
        Sweden_df2[k].fillna('', inplace=True)
# Out:
# parameterSamplingPeriod
# resultObservationStatus
# Remarks
# metadata_statements

# %%
for k,v in Sweden_df2.dtypes.to_dict().items():
    print({"name": k, "type":'string' if v == object else 'int' if v == 'int' else 'float'})
# Out:
# {'name': 'waterBodyIdentifier', 'type': 'string'}
# {'name': 'waterBodyIdentifierScheme', 'type': 'string'}
# {'name': 'parameterWaterBodyCategory', 'type': 'string'}
# {'name': 'observedPropertyDeterminandCode', 'type': 'string'}
# {'name': 'procedureAnalysedFraction', 'type': 'string'}
# {'name': 'procedureAnalysedMedia', 'type': 'string'}
# {'name': 'resultUom', 'type': 'string'}
# {'name': 'phenomenonTimeReferenceYear', 'type': 'int'}
# {'name': 'parameterSamplingPeriod', 'type': 'string'}
# {'name': 'procedureLOQValue', 'type': 'float'}
# {'name': 'resultNumberOfSamples', 'type': 'int'}
# {'name': 'resultQualityNumberOfSamplesBelowLOQ', 'type': 'float'}
# {'name': 'resultQualityMinimumBelowLOQ', 'type': 'float'}
# {'name': 'resultMinimumValue', 'type': 'float'}
# {'name': 'resultQualityMeanBelowLOQ', 'type': 'float'}
# {'name': 'resultMeanValue', 'type': 'float'}
# {'name': 'resultQualityMaximumBelowLOQ', 'type': 'float'}
# {'name': 'resultMaximumValue', 'type': 'float'}
# {'name': 'resultQualityMedianBelowLOQ', 'type': 'float'}
# {'name': 'resultMedianValue', 'type': 'float'}
# {'name': 'resultStandardDeviationValue', 'type': 'float'}
# {'name': 'resultNumberOfSitesClass1', 'type': 'float'}
# {'name': 'resultNumberOfSitesClass2', 'type': 'float'}
# {'name': 'resultNumberOfSitesClass3', 'type': 'float'}
# {'name': 'resultNumberOfSitesClass4', 'type': 'float'}
# {'name': 'resultNumberOfSitesClass5', 'type': 'float'}
# {'name': 'resultObservationStatus', 'type': 'string'}
# {'name': 'Remarks', 'type': 'string'}
# {'name': 'metadata_versionId', 'type': 'string'}
# {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'}
# {'name': 'metadata_statusCode', 'type': 'string'}
# {'name': 'metadata_observationStatus', 'type': 'string'}
# {'name': 'metadata_statements', 'type': 'string'}
# {'name': 'UID', 'type': 'int'}

# %%
schema = {
    'doc': 'Waterbase - Water quality',
    'name': 'Water Quality - BiologyEQRData',
    'namespace': 'BiologyEQRData',
    'type': 'record',
    'fields': [
        {'name': 'waterBodyIdentifier', 'type': 'string'},
        {'name': 'waterBodyIdentifierScheme', 'type': 'string'},
        {'name': 'parameterWaterBodyCategory', 'type': 'string'},
        {'name': 'observedPropertyDeterminandCode', 'type': 'string'},
        {'name': 'procedureAnalysedFraction', 'type': 'string'},
        {'name': 'procedureAnalysedMedia', 'type': 'string'},
        {'name': 'resultUom', 'type': 'string'},
        {'name': 'phenomenonTimeReferenceYear', 'type': 'int'},
        {'name': 'parameterSamplingPeriod', 'type': 'string'},
        {'name': 'procedureLOQValue', 'type': 'float'},
        {'name': 'resultNumberOfSamples', 'type': 'int'},
        {'name': 'resultQualityNumberOfSamplesBelowLOQ', 'type': 'float'},
        {'name': 'resultQualityMinimumBelowLOQ', 'type': 'float'},
        {'name': 'resultMinimumValue', 'type': 'float'},
        {'name': 'resultQualityMeanBelowLOQ', 'type': 'float'},
        {'name': 'resultMeanValue', 'type': 'float'},
        {'name': 'resultQualityMaximumBelowLOQ', 'type': 'float'},
        {'name': 'resultMaximumValue', 'type': 'float'},
        {'name': 'resultQualityMedianBelowLOQ', 'type': 'float'},
        {'name': 'resultMedianValue', 'type': 'float'},
        {'name': 'resultStandardDeviationValue', 'type': 'float'},
        {'name': 'resultNumberOfSitesClass1', 'type': 'float'},
        {'name': 'resultNumberOfSitesClass2', 'type': 'float'},
        {'name': 'resultNumberOfSitesClass3', 'type': 'float'},
        {'name': 'resultNumberOfSitesClass4', 'type': 'float'},
        {'name': 'resultNumberOfSitesClass5', 'type': 'float'},
        {'name': 'resultObservationStatus', 'type': 'string'},
        {'name': 'Remarks', 'type': 'string'},
        {'name': 'metadata_versionId', 'type': 'string'},
        {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'},
        {'name': 'metadata_statusCode', 'type': 'string'},
        {'name': 'metadata_observationStatus', 'type': 'string'},
        {'name': 'metadata_statements', 'type': 'string'},
        {'name': 'UID', 'type': 'int'},
    ]
}
parsed_schema = parse_schema(schema)

# %%
# 2. Convert pd.DataFrame to records - list of dictionaries
records = Sweden_df2.to_dict('records')

# 3. Write to Avro file
with open('Waterbase_v2018_1_T_WISE4_AggregatedDataByWaterBody.avro', 'wb') as out:
    writer(out, parsed_schema, records)

# %%
df3.columns
# Out:
# Index(['CountryCode', 'observedPropertyDeterminandBiologyEQRCode',
#        'parameterWaterBodyCategory', 'parameterNCSWaterBodyType',
#        'parameterWFDIntercalibrationWaterBodyType', 'parameterNaturalAWBHMWB',
#        'parameterICStatusOfDeterminandBiologyEQR',
#        'parameterBoundaryValueClasses12', 'parameterBoundaryValueClasses23',
#        'parameterBoundaryValueClasses34', 'parameterBoundaryValueClasses45',
#        'procedureBiologicalAnalyticalMethodDescription',
#        'resultObservationStatus', 'Remarks', 'metadata_versionId',
#        'metadata_beginLifeSpanVersion', 'metadata_statusCode',
#        'metadata_observationStatus', 'metadata_statements', 'UID'],
#       dtype='object')

# %%
Sweden_df3 = df3[
    df3.CountryCode == 'SE'
]

# %%
for k,v in Sweden_df3.dtypes.to_dict().items():
    if v == object and Sweden_df3[k].isna().sum():
        print(k)
        Sweden_df3[k].fillna('', inplace=True)
# Out:
# parameterWFDIntercalibrationWaterBodyType
# procedureBiologicalAnalyticalMethodDescription
# resultObservationStatus
# Remarks
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
for k,v in Sweden_df3.dtypes.to_dict().items():
    print({"name": k, "type":'string' if v == object else 'int' if v == 'int' else 'float'})
# Out:
# {'name': 'CountryCode', 'type': 'string'}
# {'name': 'observedPropertyDeterminandBiologyEQRCode', 'type': 'string'}
# {'name': 'parameterWaterBodyCategory', 'type': 'string'}
# {'name': 'parameterNCSWaterBodyType', 'type': 'string'}
# {'name': 'parameterWFDIntercalibrationWaterBodyType', 'type': 'string'}
# {'name': 'parameterNaturalAWBHMWB', 'type': 'string'}
# {'name': 'parameterICStatusOfDeterminandBiologyEQR', 'type': 'int'}
# {'name': 'parameterBoundaryValueClasses12', 'type': 'float'}
# {'name': 'parameterBoundaryValueClasses23', 'type': 'float'}
# {'name': 'parameterBoundaryValueClasses34', 'type': 'float'}
# {'name': 'parameterBoundaryValueClasses45', 'type': 'float'}
# {'name': 'procedureBiologicalAnalyticalMethodDescription', 'type': 'string'}
# {'name': 'resultObservationStatus', 'type': 'string'}
# {'name': 'Remarks', 'type': 'string'}
# {'name': 'metadata_versionId', 'type': 'string'}
# {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'}
# {'name': 'metadata_statusCode', 'type': 'string'}
# {'name': 'metadata_observationStatus', 'type': 'string'}
# {'name': 'metadata_statements', 'type': 'float'}
# {'name': 'UID', 'type': 'int'}

# %%
schema = {
    'doc': 'Waterbase - Water quality',
    'name': 'Water Quality - BiologyEQRData',
    'namespace': 'BiologyEQRData',
    'type': 'record',
    'fields': [
        {'name': 'CountryCode', 'type': 'string'},
        {'name': 'observedPropertyDeterminandBiologyEQRCode', 'type': 'string'},
        {'name': 'parameterWaterBodyCategory', 'type': 'string'},
        {'name': 'parameterNCSWaterBodyType', 'type': 'string'},
        {'name': 'parameterWFDIntercalibrationWaterBodyType', 'type': 'string'},
        {'name': 'parameterNaturalAWBHMWB', 'type': 'string'},
        {'name': 'parameterICStatusOfDeterminandBiologyEQR', 'type': 'int'},
        {'name': 'parameterBoundaryValueClasses12', 'type': 'float'},
        {'name': 'parameterBoundaryValueClasses23', 'type': 'float'},
        {'name': 'parameterBoundaryValueClasses34', 'type': 'float'},
        {'name': 'parameterBoundaryValueClasses45', 'type': 'float'},
        {'name': 'procedureBiologicalAnalyticalMethodDescription', 'type': 'string'},
        {'name': 'resultObservationStatus', 'type': 'string'},
        {'name': 'Remarks', 'type': 'string'},
        {'name': 'metadata_versionId', 'type': 'string'},
        {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'},
        {'name': 'metadata_statusCode', 'type': 'string'},
        {'name': 'metadata_observationStatus', 'type': 'string'},
        {'name': 'metadata_statements', 'type': 'float'},
        {'name': 'UID', 'type': 'int'},
    ]
}
parsed_schema = parse_schema(schema)

# %%
# 2. Convert pd.DataFrame to records - list of dictionaries
records = Sweden_df3.to_dict('records')

# 3. Write to Avro file
with open('Waterbase_v2018_1_T_WISE4_BiologyEQRClassificationProcedure.avro', 'wb') as out:
    writer(out, parsed_schema, records)

# %%
df5.columns
# Out:
# Index(['monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
#        'parameterWaterBodyCategory', 'observedPropertyDeterminandCode',
#        'procedureAnalysedFraction', 'procedureAnalysedMedia', 'resultUom',
#        'phenomenonTimeSamplingDate', 'resultObservedValue',
#        'resultQualityObservedValueBelowLOQ', 'procedureLOQValue',
#        'procedureAnalyticalMethod', 'parameterSampleDepth',
#        'resultObservationStatus', 'Remarks', 'metadata_versionId',
#        'metadata_beginLifeSpanVersion', 'metadata_statusCode',
#        'metadata_observationStatus', 'metadata_statements', 'UID'],
#       dtype='object')

# %%
Sweden_df4.columns
# Out:
# Index(['monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
#        'parameterWaterBodyCategory', 'parameterNCSWaterBodyType',
#        'observedPropertyDeterminandBiologyEQRCode',
#        'phenomenonTimeReferenceYear', 'parameterSamplingPeriod',
#        'resultEcologicalStatusClassValue', 'resultNumberOfSamples',
#        'resultEQRValue', 'resultNormalisedEQRValue', 'resultObservationStatus',
#        'Remarks', 'metadata_versionId', 'metadata_beginLifeSpanVersion',
#        'metadata_statusCode', 'metadata_observationStatus',
#        'metadata_statements', 'UID'],
#       dtype='object')

# %%
Sweden_df5 = df5[
    df5.monitoringSiteIdentifier.isin(Sweden_df4.monitoringSiteIdentifier.unique())
].reset_index(drop=True)

# %%
for k,v in Sweden_df5.dtypes.to_dict().items():
    if v == object and Sweden_df5[k].isna().sum():
        print(k)
        Sweden_df5[k].fillna('', inplace=True)
# Out:
# procedureAnalyticalMethod
# resultObservationStatus
# Remarks
# metadata_statements

# %%
for k,v in Sweden_df5.dtypes.to_dict().items():
    print({"name": k, "type":'string' if v == object else 'int' if v == 'int' else 'float'})
# Out:
# {'name': 'monitoringSiteIdentifier', 'type': 'string'}
# {'name': 'monitoringSiteIdentifierScheme', 'type': 'string'}
# {'name': 'parameterWaterBodyCategory', 'type': 'string'}
# {'name': 'observedPropertyDeterminandCode', 'type': 'string'}
# {'name': 'procedureAnalysedFraction', 'type': 'string'}
# {'name': 'procedureAnalysedMedia', 'type': 'string'}
# {'name': 'resultUom', 'type': 'string'}
# {'name': 'phenomenonTimeSamplingDate', 'type': 'string'}
# {'name': 'resultObservedValue', 'type': 'float'}
# {'name': 'resultQualityObservedValueBelowLOQ', 'type': 'int'}
# {'name': 'procedureLOQValue', 'type': 'float'}
# {'name': 'procedureAnalyticalMethod', 'type': 'string'}
# {'name': 'parameterSampleDepth', 'type': 'float'}
# {'name': 'resultObservationStatus', 'type': 'string'}
# {'name': 'Remarks', 'type': 'string'}
# {'name': 'metadata_versionId', 'type': 'string'}
# {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'}
# {'name': 'metadata_statusCode', 'type': 'string'}
# {'name': 'metadata_observationStatus', 'type': 'string'}
# {'name': 'metadata_statements', 'type': 'string'}
# {'name': 'UID', 'type': 'int'}

# %%
schema = {
    'doc': 'Waterbase - Water quality',
    'name': 'Water Quality - BiologyEQRData',
    'namespace': 'BiologyEQRData',
    'type': 'record',
    'fields': [
        {'name': 'monitoringSiteIdentifier', 'type': 'string'},
        {'name': 'monitoringSiteIdentifierScheme', 'type': 'string'},
        {'name': 'parameterWaterBodyCategory', 'type': 'string'},
        {'name': 'observedPropertyDeterminandCode', 'type': 'string'},
        {'name': 'procedureAnalysedFraction', 'type': 'string'},
        {'name': 'procedureAnalysedMedia', 'type': 'string'},
        {'name': 'resultUom', 'type': 'string'},
        {'name': 'phenomenonTimeSamplingDate', 'type': 'string'},
        {'name': 'resultObservedValue', 'type': 'float'},
        {'name': 'resultQualityObservedValueBelowLOQ', 'type': 'int'},
        {'name': 'procedureLOQValue', 'type': 'float'},
        {'name': 'procedureAnalyticalMethod', 'type': 'string'},
        {'name': 'parameterSampleDepth', 'type': 'float'},
        {'name': 'resultObservationStatus', 'type': 'string'},
        {'name': 'Remarks', 'type': 'string'},
        {'name': 'metadata_versionId', 'type': 'string'},
        {'name': 'metadata_beginLifeSpanVersion', 'type': 'string'},
        {'name': 'metadata_statusCode', 'type': 'string'},
        {'name': 'metadata_observationStatus', 'type': 'string'},
        {'name': 'metadata_statements', 'type': 'string'},
        {'name': 'UID', 'type': 'int'},
    ]
}
parsed_schema = parse_schema(schema)

# %%
# 2. Convert pd.DataFrame to records - list of dictionaries
records = Sweden_df5.to_dict('records')

# 3. Write to Avro file
with open('Waterbase_v2018_1_T_WISE4_DisaggregatedData.avro', 'wb') as out:
    writer(out, parsed_schema, records)
